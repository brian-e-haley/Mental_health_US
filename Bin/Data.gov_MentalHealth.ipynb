# %%
# Initialising and importing
# %autosave 300
import pandas as pd
# Out:
# Autosaving every 300 seconds

# %%
# Saving file path for csv file to clean
csv_path = '../Resources/Data.gov/US_CDI.csv'

# %%
data_gov_raw = pd.read_csv(csv_path)
# Out:
# C:\Users\brian\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_gov_raw.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# ...

# %%
#data_gov_raw.columns

# %%
#data_gov_raw.dtypes

# %%
data_gov_Mental_Health = data_gov_raw.loc[(data_gov_raw['Topic'] == 'Mental Health')
                                          & (data_gov_raw['Question'] == 'Recent mentally unhealthy days among adults aged >= 18 years')]
data_gov_Mental_Health = data_gov_Mental_Health.dropna(axis = 1, how = 'all')

# %%
data_gov_Mental_Health.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DatavalueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'GeoLocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
data_gov_Mental_Health.count()
# Out:
# YearStart                    5220
# YearEnd                      5220
# LocationAbbr                 5220
# LocationDesc                 5220
# DataSource                   5220
# Topic                        5220
# Question                     5220
# DataValueUnit                5220
# DataValueType                5220
# DataValue                    4508
# DataValueAlt                 4508
# DataValueFootnoteSymbol       748
# DatavalueFootnote             748
# LowConfidenceLimit           4508
# HighConfidenceLimit          4508
# StratificationCategory1      5220
# Stratification1              5220
# GeoLocation                  5184
# LocationID                   5220
# TopicID                      5220
# QuestionID                   5220
# DataValueTypeID              5220
# StratificationCategoryID1    5220
# StratificationID1            5220
# dtype: int64

# %%
data_gov_Mental_Health.head()
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 16060       2016     2016           UT         Utah      BRFSS  Mental Health
# 16142       2016     2016           VT      Vermont      BRFSS  Mental Health
# 16437       2016     2016           VA     Virginia      BRFSS  Mental Health
# 17827       2016     2016           PR  Puerto Rico      BRFSS  Mental Health
# 17919       2016     2016           IL     Illinois      BRFSS  Mental Health
#
#                                                 Question Response  \
# 16060  Recent mentally unhealthy days among adults ag...      NaN
# 16142  Recent mentally unhealthy days among adults ag...      NaN
# 16437  Recent mentally unhealthy days among adults ag...      NaN
# 17827  Recent mentally unhealthy days among adults ag...      NaN
# 17919  Recent mentally unhealthy days among adults ag...      NaN
#
#       DataValueUnit DataValueType        ...        LocationID  TopicID  \
# ...

# %%
data_gov_Mental_Health.to_csv(path_or_buf = '../Resources/Data.gov/US_CDI_Mental_Health.csv')
